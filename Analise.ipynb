# %%
import matplotlib.pyplot as plt

# %%
arvore=[0.76905311778291, 0.5577367205542725, 1.3660508083140877, 0.704243648960739, 0.8292436489607391]
barramento=[1.2450980392156863, 0.01960784313725488, 1.6764705882352942, 0.5490196078431372, 0.9313725490196079]
estrela=[0.4629629629629629, 0.6342592592592593, 1.6342592592592593, 0.8171296296296297, 0.9421296296296298]
pontoa=[0.6847133757961784, 0.12544663663197142, 1.4669100512661177, 0.6931800528196363, 0.6443995650147585]

# %%
labels = [f"Nó {i+1}" for i in range(len(arvore))]
plt.figure(figsize=(10, 6))
plt.plot(labels, arvore, label='Árvore', marker='o', linestyle='-', color='b')
plt.plot(labels, barramento, label='Barramento', marker='o', linestyle='--', color='g')
plt.plot(labels, estrela, label='Estrela', marker='o', linestyle='-.', color='r')
plt.plot(labels, pontoa, label='Ponto A', marker='o', linestyle=':', color='m')
plt.title('Análise de Fluxo de Tráfego de Dados')
plt.xlabel('Situações')
plt.ylabel('Fluxo de Dados')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Out:
# arvore: Erro absoluto = 0.808314, Erro relativo = 0.591716
# barramento: Erro absoluto = 1.656863, Erro relativo = 0.988304
# estrela: Erro absoluto = 1.171296, Erro relativo = 0.716714
# pontoa: Erro absoluto = 1.341463, Erro relativo = 0.914482
