# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '.')))
from utils import functions

# %%
A = [
[200, 100, 100, 0],
[100, 400, 100, 0],
[0, 100, 200, 50],
[0, 0, 50, 300]
]
b = [500, 300, 400, 350]

# %%
functions.plot_graph(A)

# %%
functions.plotar_conexoes(A)

# %%
print("Solução do sistema:", functions.eliminacao_gauss(A, b, 1))
functions.analisar_variacao(A, b, 4, functions.eliminacao_gauss)
# Out:
# Solução do sistema: [1.6375838926174497, -0.12080536912751674, 1.8456375838926173, 0.8590604026845637]

# %%
print("Solução pelo método de Jacobi:", functions.metodo_jacobi(A, b, 3))
functions.analisar_variacao(A, b, 4, functions.metodo_jacobi)
# Out:
# Solução pelo método de Jacobi: [1.6541042849767684, -0.12080536912751674, 1.8456375838926173, 0.8590604026845637]

# %%
print("Solução pelo método de Gauss-Seidel:", functions.metodo_gauss_seidel(A, b, 2))
functions.analisar_variacao(A, b, 5, functions.metodo_gauss_seidel)
# Out:
# Solução pelo método de Gauss-Seidel: [1.3901098901098903, -0.15384615384615385, 1.8456375838926173, 0.8590604026845637]

# %%
erroAbs=functions.erroAbsoluto(A, b, functions.metodo_jacobi(A, b, 2))
print(erroAbs)
print(functions.erroRelativo(erroAbs, b))
print(b)
print(functions.Ax(A, functions.metodo_jacobi(A, b, 2)))
# Out:
# [52.79887897337562, 11.564274651522986, 0.0, 0.0]
# [0.10559775794675125, 0.23128549303045973, 0.0, 0.0]
# [500, 50.0, 385.7142857142857, 246.15384615384616]
# [447.2011210266244, 38.435725348477014, 385.7142857142857, 246.15384615384616]
