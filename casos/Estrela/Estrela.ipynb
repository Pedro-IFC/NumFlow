# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))
from utils import functions

# %%
A = [
[400, 100, 100, 50, 50],
[100, 400, 0, 0, 0],
[100, 0, 400, 0, 0],
[50, 0, 0, 400, 0],
[50, 0, 0, 0, 400],
]
b = [500, 300, 700, 350, 400]

# %%
functions.plot_graph(A)

# %%
functions.plotar_conexoes(A)

# %%
print("Solução do sistema:", functions.eliminacao_gauss(A, b, 1))
functions.analisar_variacao(A, b, 4, functions.eliminacao_gauss)
# Out:
# Solução do sistema: [0.4629629629629629, 0.6342592592592593, 1.6342592592592593, 0.8171296296296297, 0.9421296296296298]

# %%
print("Solução pelo método de Jacobi:", functions.metodo_jacobi(A, b, 3))
functions.analisar_variacao(A, b, 4, functions.metodo_jacobi)
# Out:
# Solução pelo método de Jacobi: [0.46430583112874774, 0.6342184744268078, 1.6342592592592593, 0.8171296296296297, 0.9421296296296298]

# %%
print("Solução pelo método de Gauss-Seidel:", functions.metodo_gauss_seidel(A, b, 2))
functions.analisar_variacao(A, b, 5, functions.metodo_gauss_seidel)
# Out:
# Solução pelo método de Gauss-Seidel: [0.5227099867724868, 0.6294995590828925, 1.6336474867724868, 0.8171296296296297, 0.9421296296296298]

# %%
erroAbs=functions.erroAbsoluto(A, b, functions.metodo_gauss_seidel(A, b, 1))
print(erroAbs)
print(functions.erroRelativo(erroAbs, b))
# Out:
# [290.91600529100526, 61.06233465608466, 23.228395061728406, 6.729497354497369, 0.0]
# [0.5818320105820105, 0.348927626606198, 0.039593855218855244, 0.021412037037037084, 0.0]
