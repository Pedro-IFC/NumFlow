# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))
from utils import functions

# %%
A = [
[400, 100, 100, 50, 50],
[100, 400, 100, 50, 0],
[100, 100, 400, 0, 50],
[50, 50, 0, 400, 50],
[50, 0, 50, 50, 400],
]
b = [500, 300, 700, 350, 400]

# %%
functions.plot_graph(A)

# %%
functions.plotar_conexoes(A)

# %%
print("Solução do sistema:", functions.eliminacao_gauss(A, b, 1))
functions.analisar_variacao(A, b, 4, functions.eliminacao_gauss)
# Out:
# Solução do sistema: [0.6847133757961784, 0.12544663663197142, 1.4669100512661177, 0.6931800528196363, 0.6443995650147585]

# %%
print("Solução pelo método de Jacobi:", functions.metodo_jacobi(A, b, 3))
functions.analisar_variacao(A, b, 4, functions.metodo_jacobi)
# Out:
# Solução pelo método de Jacobi: [0.6872373012174162, 0.12457720864742775, 1.4669100512661177, 0.6931800528196363, 0.6443995650147585]

# %%
print("Solução pelo método de Gauss-Seidel:", functions.metodo_gauss_seidel(A, b, 2))
functions.analisar_variacao(A, b, 5, functions.metodo_gauss_seidel)
# Out:
# Solução pelo método de Gauss-Seidel: [0.5813548162779171, 0.11100379502430148, 1.4712571911888364, 0.6931800528196363, 0.6443995650147585]

# %%
erroAbs=functions.erroAbsoluto(A, b, functions.metodo_gauss_seidel(A, b, 1))
print(erroAbs)
print(functions.erroRelativo(erroAbs, b))
# Out:
# [267.4580734888332, 133.37357686588695, 10.347411172018951, 30.429979459030278, 0.0]
# [0.5349161469776663, 0.7621347249479254, 0.019161872540775837, 0.10143326486343426, 0.0]
